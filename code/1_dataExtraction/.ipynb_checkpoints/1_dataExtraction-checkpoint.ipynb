# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import librosa
import pandas as pd

# %%
def featureExtraction(path):
    X, sample_rate = librosa.load(path)
    stft = np.abs(librosa.stft(X))
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
    return mfccs, chroma, mel, contrast, tonnetz

# %%
cols = ['emotion', 'intensity', 'gender', 'chr_mn', 'chr_std', 'cont_mn', 'cont_std', 'ton_mn', 'ton_std', 'mel02_mn', 'mel02_std', 'mel24_mn', 'mel24_std', 'mel46_mn', 'mel46_std', 'mel68_mn', 'mel68_std']
initDict = dict()
for i in cols:
    initDict[i] = list()
    
df = pd.DataFrame(initDict)

# %%
dataset = "../dataset/ravdess"
actors = os.listdir(dataset)

for fld in actors:
    path = "../dataset/ravdess/"+fld+"/"
    aFiles = os.listdir(path)
    for i in aFiles:
        details = dict()
        fileName = path + i
        mfccs, chroma, mel, contrast, tonnetz = featureExtraction(fileName)

        details['emotion'] = int(i[6:8])
        details['intensity'] = int(i[9:11])
        details['gender'] = int(i[18:20])%2 # 1: male, 0: female

        details['chr_mn'] = np.mean(chroma)
        details['chr_std'] = np.std(chroma)
        details['cont_mn'] = np.mean(contrast)
        details['cont_std'] = np.std(contrast)
        details['ton_mn'] = np.mean(tonnetz)
        details['ton_std'] = np.std(tonnetz)

        details['mel02_mn'] = np.mean(mel[0:20])
        details['mel02_std'] = np.std(mel[0:20])
        details['mel24_mn'] = np.mean(mel[20:40])
        details['mel24_std'] = np.std(mel[20:40])
        details['mel46_mn'] = np.mean(mel[40:60])
        details['mel46_std'] = np.std(mel[40:60])
        details['mel68_mn'] = np.mean(mel[60:80])
        details['mel68_std'] = np.std(mel[60:80])

        df = df.append(details, ignore_index=True)
    print("Finished Folder :", fld)
    df.to_csv('../extractedData/details.csv', index=False)
# Out:
# Finished Folder : Actor_01
# Finished Folder : Actor_02
# Finished Folder : Actor_03
# Finished Folder : Actor_04
# Finished Folder : Actor_05

# %% [markdown]
# #### SOME HELPER CODE FOR VISUALISATION ONLY >>> "NOT" TO BE RUN

# %%
i = "01-02-03-04-05-06-07.wav"
#----01234567890123456789
#3 - >emotion
#4-> intensity
#7-> gender

emotion = int(i[6:8])
intensity = int(i[9:11])
gender = int(i[18:20])%2 # 1: male, 0: female

gender
# Out:
# 1

# %%
plt.plot(mfccs)

# %%
plt.plot(mfccs)

# %%
plt.plot(chroma)

# %%
plt.plot(mel)

# %%
plt.plot(mel)

# %%
plt.plot(contrast)

# %%
plt.plot(contrast)

# %%
plt.plot(tonnetz)
